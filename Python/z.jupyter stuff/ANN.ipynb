# %% [markdown]
# # Artificial Neural Networks Exercise ( Classification of Diabetes Patients )

# %% [markdown]
# In this tutorial, you will discover how to create your first deep learning neural network model in Python using Keras.
# There is not a lot of code required, but we are going to step over it slowly so that you will know how to create your own models in the future.
#
# The steps you are going to cover in this tutorial are as follows:
#
#     Load Data.
#
#     Define Keras Model.
#
#     Compile Keras Model.
#
#     Fit Keras Model.
#
#     Evaluate Keras Model.
#
#     Make Predictions

# %% [markdown]
# ###########################################################################################

# %% [markdown]
# We will use the NumPy library to load our dataset and we will use two classes from the Keras library to define our model.
#
# The imports required are listed below.

# %%
# first neural network with keras tutorial
from numpy import loadtxt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import pandas as pd

# %% [markdown]
# In this tutorial, we are going to use the Pima Indians onset of diabetes dataset. This is a standard machine learning dataset from the UCI Machine Learning repository. It describes patient medical record data for Pima Indians and whether they had an onset of diabetes within five years.
#
# As such, it is a binary classification problem (onset of diabetes as 1 or not as 0). All of the input variables that describe each patient are numerical. This makes it easy to use directly with neural networks that expect numerical input and output values, and ideal for our first neural network in Keras.

# %% [markdown]
# # Load the Dataset

# %%
# load the dataset
dataset = loadtxt('pima-indians-diabetes.csv', delimiter=',')
df = pd.read_csv('pima-indians-diabetes.csv', sep=',', 
                 names=["No pregnant", "Plasma glucose", "Diastolic blood", "Triceps skin thickness",
                       "2-Hour serum insulin","BMI","Diabetes pedigree","Age","Class variable"])
# split into input (X) and output (y) variables
X = dataset[:,0:8]
y = dataset[:,8]
df
# Out:
#      No pregnant  Plasma glucose  Diastolic blood  Triceps skin thickness  \
# 0              6             148               72                      35
# 1              1              85               66                      29
# 2              8             183               64                       0
# 3              1              89               66                      23
# 4              0             137               40                      35
# ..           ...             ...              ...                     ...
# 763           10             101               76                      48
# 764            2             122               70                      27
# 765            5             121               72                      23
# 766            1             126               60                       0
# 767            1              93               70                      31
#
#      2-Hour serum insulin   BMI  Diabetes pedigree  Age  Class variable
# 0                       0  33.6              0.627   50               1
# 1                       0  26.6              0.351   31               0
# 2                       0  23.3              0.672   32               1
# 3                      94  28.1              0.167   21               0
# 4                     168  43.1              2.288   33               1
# ..                    ...   ...                ...  ...             ...
# 763                   180  32.9              0.171   63               0
# 764                     0  36.8              0.340   27               0
# 765                   112  26.2              0.245   30               0
# 766                     0  30.1              0.349   47               1
# 767                     0  30.4              0.315   23               0
#
# [768 rows x 9 columns]

# %% [markdown]
# The variables can be summarized as follows:
#
# Input Variables (X):
#
#     Number of times pregnant
#
#     Plasma glucose concentration a 2 hours in an oral glucose tolerance test
#
#     Diastolic blood pressure (mm Hg)
#
#     Triceps skin fold thickness (mm)
#
#     2-Hour serum insulin (mu U/ml)
#
#     Body mass index (weight in kg/(height in m)^2)
#
#     Diabetes pedigree function
#
#     Age (years)
#
# Output Variables (y):
#
#     Class variable (0 or 1)

# %% [markdown]
# Models in Keras are defined as a sequence of layers.
#
# We create a Sequential model and add layers one at a time until we are happy with our network architecture.
#
# The first thing to get right is to ensure the input layer has the right number of input features. This can be specified when creating the first layer with the input_dim argument and setting it to 8 for the 8 input variables.
#
# In this example, we will use a fully-connected network structure with three layers.
#
# Fully connected layers are defined using the Dense class. We can specify the number of neurons or nodes in the layer as the first argument, and specify the activation function using the activation argument.
#
# We will use the rectified linear unit activation function referred to as ReLU on the first two layers and the Sigmoid function in the output layer.
#
# It used to be the case that Sigmoid and Tanh activation functions were preferred for all layers. These days, better performance is achieved using the ReLU activation function. We use a sigmoid on the output layer to ensure our network output is between 0 and 1 and easy to map to either a probability of class 1 or snap to a hard classification of either class with a default threshold of 0.5.
#
#
# We can piece it all together by adding each layer:
#
#     The model expects rows of data with 8 variables (the input_dim=8 argument)
#     The first hidden layer has 12 nodes and uses the relu activation function.
#     The second hidden layer has 8 nodes and uses the relu activation function.
#     The output layer has one node and uses the sigmoid activation function.

# %%
model = Sequential()
model.add(Dense(12, input_dim=8, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %% [markdown]
# When compiling, we must specify some additional properties required when training the network. Remember training a network means finding the best set of weights to map inputs to outputs in our dataset.
#
# We must specify the loss function to use to evaluate a set of weights, the optimizer is used to search through different weights for the network and any optional metrics we would like to collect and report during training.
#
# This loss is for a binary classification problems and is defined in Keras as “binary_crossentropy“.
#
# We will define the optimizer as the efficient stochastic gradient descent algorithm “adam“. This is a popular version of gradient descent because it automatically tunes itself and gives good results in a wide range of problems.

# %%
# compile the keras model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# Now it is time to execute the model on some data.
#
# We can train or fit our model on our loaded data by calling the fit() function on the model.
#
# Training occurs over epochs and each epoch is split into batches.
#
#     Epoch: One pass through all of the rows in the training dataset.
#     Batch: One or more samples considered by the model within an epoch before weights are updated.

# %%
# fit the keras model on the dataset
model.fit(X, y, epochs=150, batch_size=10)
# Out:
# Epoch 1/150
# 77/77 [==============================] - 0s 1ms/step - loss: 6.6142 - accuracy: 0.6263
# Epoch 2/150
# 77/77 [==============================] - 0s 1ms/step - loss: 1.4869 - accuracy: 0.5638
# Epoch 3/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.9193 - accuracy: 0.5885
# Epoch 4/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.8397 - accuracy: 0.5911
# Epoch 5/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.7619 - accuracy: 0.6133
# Epoch 6/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.7271 - accuracy: 0.6393
# Epoch 7/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.7218 - accuracy: 0.6380
# Epoch 8/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.7091 - accuracy: 0.6302: 0s - loss: 0.7154 - accuracy: 0.61
# Epoch 9/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.6831 - accuracy: 0.6497
# Epoch 10/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.6507 - accuracy: 0.6667
# Epoch 11/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.6556 - accuracy: 0.6471
# Epoch 12/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.6400 - accuracy: 0.6680
# Epoch 13/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.6151 - accuracy: 0.6771
# Epoch 14/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.6354 - accuracy: 0.6523
# Epoch 15/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.6143 - accuracy: 0.6784
# Epoch 16/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.6267 - accuracy: 0.6719
# Epoch 17/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5997 - accuracy: 0.7005
# Epoch 18/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5948 - accuracy: 0.7005
# Epoch 19/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5997 - accuracy: 0.7096
# Epoch 20/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5896 - accuracy: 0.6979
# Epoch 21/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5863 - accuracy: 0.7031
# Epoch 22/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5927 - accuracy: 0.7122
# Epoch 23/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5779 - accuracy: 0.7188
# Epoch 24/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5801 - accuracy: 0.7188
# Epoch 25/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5780 - accuracy: 0.6953
# Epoch 26/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5816 - accuracy: 0.7188
# Epoch 27/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5889 - accuracy: 0.7005
# Epoch 28/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5787 - accuracy: 0.7096
# Epoch 29/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5718 - accuracy: 0.7279
# Epoch 30/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5584 - accuracy: 0.7305
# Epoch 31/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5683 - accuracy: 0.7070
# Epoch 32/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5536 - accuracy: 0.7292
# Epoch 33/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5629 - accuracy: 0.7174
# Epoch 34/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5603 - accuracy: 0.7344
# Epoch 35/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5489 - accuracy: 0.7240
# Epoch 36/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5596 - accuracy: 0.7148
# Epoch 37/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5812 - accuracy: 0.7122
# Epoch 38/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5501 - accuracy: 0.7279
# Epoch 39/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5624 - accuracy: 0.7174
# Epoch 40/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5512 - accuracy: 0.7214
# Epoch 41/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5647 - accuracy: 0.7096
# Epoch 42/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5513 - accuracy: 0.7214
# Epoch 43/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5526 - accuracy: 0.7188
# Epoch 44/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5491 - accuracy: 0.7253
# Epoch 45/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5425 - accuracy: 0.7344
# Epoch 46/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5417 - accuracy: 0.7318
# Epoch 47/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5435 - accuracy: 0.7383
# Epoch 48/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5420 - accuracy: 0.7253
# Epoch 49/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5364 - accuracy: 0.7227
# Epoch 50/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5445 - accuracy: 0.7344
# Epoch 51/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5409 - accuracy: 0.7109
# Epoch 52/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5334 - accuracy: 0.7383
# Epoch 53/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5355 - accuracy: 0.7305
# Epoch 54/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5411 - accuracy: 0.7370
# Epoch 55/150
# 77/77 [==============================] - 0s 999us/step - loss: 0.5352 - accuracy: 0.7396
# Epoch 56/150
# 77/77 [==============================] - 0s 986us/step - loss: 0.5405 - accuracy: 0.7422
# Epoch 57/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5337 - accuracy: 0.7474
# Epoch 58/150
# 77/77 [==============================] - 0s 973us/step - loss: 0.5510 - accuracy: 0.7331
# Epoch 59/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5283 - accuracy: 0.7526
# Epoch 60/150
# 77/77 [==============================] - 0s 960us/step - loss: 0.5321 - accuracy: 0.7227
# Epoch 61/150
# 77/77 [==============================] - 0s 999us/step - loss: 0.5311 - accuracy: 0.7396
# Epoch 62/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5332 - accuracy: 0.7409
# Epoch 63/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5209 - accuracy: 0.7331
# Epoch 64/150
# 77/77 [==============================] - 0s 973us/step - loss: 0.5306 - accuracy: 0.7383
# Epoch 65/150
# 77/77 [==============================] - 0s 963us/step - loss: 0.5284 - accuracy: 0.7461
# Epoch 66/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5205 - accuracy: 0.7370
# Epoch 67/150
# 77/77 [==============================] - 0s 1000us/step - loss: 0.5161 - accuracy: 0.7552
# Epoch 68/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5255 - accuracy: 0.7448
# Epoch 69/150
# 77/77 [==============================] - 0s 999us/step - loss: 0.5414 - accuracy: 0.7174
# Epoch 70/150
# 77/77 [==============================] - 0s 986us/step - loss: 0.5226 - accuracy: 0.7383
# Epoch 71/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5255 - accuracy: 0.7500
# Epoch 72/150
# 77/77 [==============================] - 0s 986us/step - loss: 0.5196 - accuracy: 0.7370
# Epoch 73/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5220 - accuracy: 0.7370
# Epoch 74/150
# 77/77 [==============================] - 0s 998us/step - loss: 0.5190 - accuracy: 0.7448
# Epoch 75/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5226 - accuracy: 0.7396
# Epoch 76/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5218 - accuracy: 0.7253
# Epoch 77/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5339 - accuracy: 0.7370
# Epoch 78/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5387 - accuracy: 0.7305
# Epoch 79/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5139 - accuracy: 0.7357
# Epoch 80/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5321 - accuracy: 0.7344
# Epoch 81/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5379 - accuracy: 0.7096
# Epoch 82/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5107 - accuracy: 0.7461
# Epoch 83/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5171 - accuracy: 0.7409
# Epoch 84/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5199 - accuracy: 0.7565
# Epoch 85/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5159 - accuracy: 0.7474
# Epoch 86/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5321 - accuracy: 0.7357
# Epoch 87/150
# 77/77 [==============================] - 0s 973us/step - loss: 0.5072 - accuracy: 0.7383
# Epoch 88/150
# 77/77 [==============================] - 0s 973us/step - loss: 0.5079 - accuracy: 0.7630
# Epoch 89/150
# 77/77 [==============================] - 0s 973us/step - loss: 0.5031 - accuracy: 0.7643
# Epoch 90/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5146 - accuracy: 0.7500
# Epoch 91/150
# 77/77 [==============================] - 0s 999us/step - loss: 0.5061 - accuracy: 0.7487
# Epoch 92/150
# 77/77 [==============================] - 0s 960us/step - loss: 0.5150 - accuracy: 0.7500
# Epoch 93/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5033 - accuracy: 0.7604
# Epoch 94/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5029 - accuracy: 0.7487
# Epoch 95/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5054 - accuracy: 0.7552
# Epoch 96/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5314 - accuracy: 0.7383: 0s - loss: 0.5025 - accuracy: 0.75
# Epoch 97/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5042 - accuracy: 0.7448
# Epoch 98/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5076 - accuracy: 0.7552
# Epoch 99/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5105 - accuracy: 0.7513
# Epoch 100/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5006 - accuracy: 0.7526
# Epoch 101/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5219 - accuracy: 0.7318
# Epoch 102/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5069 - accuracy: 0.7331
# Epoch 103/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5060 - accuracy: 0.7591
# Epoch 104/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5090 - accuracy: 0.7500
# Epoch 105/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4985 - accuracy: 0.7630
# Epoch 106/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5157 - accuracy: 0.7474
# Epoch 107/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5032 - accuracy: 0.7539
# Epoch 108/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4989 - accuracy: 0.7435
# Epoch 109/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5032 - accuracy: 0.7422
# Epoch 110/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4939 - accuracy: 0.7552
# Epoch 111/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5060 - accuracy: 0.7682
# Epoch 112/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5018 - accuracy: 0.7630
# Epoch 113/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5062 - accuracy: 0.7565
# Epoch 114/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4989 - accuracy: 0.7695
# Epoch 115/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4936 - accuracy: 0.7617
# Epoch 116/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4945 - accuracy: 0.7617
# Epoch 117/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4949 - accuracy: 0.7578
# Epoch 118/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4973 - accuracy: 0.7591
# Epoch 119/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4845 - accuracy: 0.7721
# Epoch 120/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5032 - accuracy: 0.7526
# Epoch 121/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4898 - accuracy: 0.7526
# Epoch 122/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5020 - accuracy: 0.7539
# Epoch 123/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5029 - accuracy: 0.7513
# Epoch 124/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4929 - accuracy: 0.7643
# Epoch 125/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4952 - accuracy: 0.7526
# Epoch 126/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4839 - accuracy: 0.7799
# Epoch 127/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4923 - accuracy: 0.7630
# Epoch 128/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4898 - accuracy: 0.7669
# Epoch 129/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4905 - accuracy: 0.7656
# Epoch 130/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4906 - accuracy: 0.7552
# Epoch 131/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4873 - accuracy: 0.7656
# Epoch 132/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4896 - accuracy: 0.7708
# Epoch 133/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4751 - accuracy: 0.7786
# Epoch 134/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4926 - accuracy: 0.7799
# Epoch 135/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4887 - accuracy: 0.7669
# Epoch 136/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4835 - accuracy: 0.7643
# Epoch 137/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4765 - accuracy: 0.7669
# Epoch 138/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4875 - accuracy: 0.7578
# Epoch 139/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4895 - accuracy: 0.7526
# Epoch 140/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5127 - accuracy: 0.7461
# Epoch 141/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4831 - accuracy: 0.7565
# Epoch 142/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4762 - accuracy: 0.7826
# Epoch 143/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4798 - accuracy: 0.7630
# Epoch 144/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4851 - accuracy: 0.7669
# Epoch 145/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4804 - accuracy: 0.7773
# Epoch 146/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4929 - accuracy: 0.7500
# Epoch 147/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4743 - accuracy: 0.7747
# Epoch 148/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4740 - accuracy: 0.7786
# Epoch 149/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4749 - accuracy: 0.7773
# Epoch 150/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4785 - accuracy: 0.7799

# %% [markdown]
# We have trained our neural network on the entire dataset and we can evaluate the performance of the network on the same dataset.
#
# This will only give us an idea of how well we have modeled the dataset (e.g. train accuracy), but no idea of how well the algorithm might perform on new data.

# %%
# evaluate the keras model
_, accuracy = model.evaluate(X, y)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4624 - accuracy: 0.7734
# Accuracy: 77.34

# %% [markdown]
# We can see that most rows are correctly predicted. In fact, we would expect about 76% of the rows to be correctly predicted based on our estimated performance of the model in the previous section.

# %%
predictions = model.predict_classes(X)
# summarize the first 5 cases
for i in range(20):
    print(' %-55s ENTRY PREDICTED => %d (EXPECTED TO BE %d)' % (X[i].tolist(), predictions[i], y[i]))
# Out:
# WARNING:tensorflow:From <ipython-input-7-90f4999f33fd>:1: Sequential.predict_classes (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#  [6.0, 148.0, 72.0, 35.0, 0.0, 33.6, 0.627, 50.0]        ENTRY PREDICTED => 1 (EXPECTED TO BE 1)
#  [1.0, 85.0, 66.0, 29.0, 0.0, 26.6, 0.351, 31.0]         ENTRY PREDICTED => 0 (EXPECTED TO BE 0)
#  [8.0, 183.0, 64.0, 0.0, 0.0, 23.3, 0.672, 32.0]         ENTRY PREDICTED => 1 (EXPECTED TO BE 1)
#  [1.0, 89.0, 66.0, 23.0, 94.0, 28.1, 0.167, 21.0]        ENTRY PREDICTED => 0 (EXPECTED TO BE 0)
#  [0.0, 137.0, 40.0, 35.0, 168.0, 43.1, 2.288, 33.0]      ENTRY PREDICTED => 1 (EXPECTED TO BE 1)
#  [5.0, 116.0, 74.0, 0.0, 0.0, 25.6, 0.201, 30.0]         ENTRY PREDICTED => 0 (EXPECTED TO BE 0)
#  [3.0, 78.0, 50.0, 32.0, 88.0, 31.0, 0.248, 26.0]        ENTRY PREDICTED => 0 (EXPECTED TO BE 1)
#  [10.0, 115.0, 0.0, 0.0, 0.0, 35.3, 0.134, 29.0]         ENTRY PREDICTED => 0 (EXPECTED TO BE 0)
#  [2.0, 197.0, 70.0, 45.0, 543.0, 30.5, 0.158, 53.0]      ENTRY PREDICTED => 1 (EXPECTED TO BE 1)
#  [8.0, 125.0, 96.0, 0.0, 0.0, 0.0, 0.232, 54.0]          ENTRY PREDICTED => 0 (EXPECTED TO BE 1)
#  [4.0, 110.0, 92.0, 0.0, 0.0, 37.6, 0.191, 30.0]         ENTRY PREDICTED => 0 (EXPECTED TO BE 0)
#  [10.0, 168.0, 74.0, 0.0, 0.0, 38.0, 0.537, 34.0]        ENTRY PREDICTED => 1 (EXPECTED TO BE 1)
#  [10.0, 139.0, 80.0, 0.0, 0.0, 27.1, 1.441, 57.0]        ENTRY PREDICTED => 1 (EXPECTED TO BE 0)
#  [1.0, 189.0, 60.0, 23.0, 846.0, 30.1, 0.398, 59.0]      ENTRY PREDICTED => 1 (EXPECTED TO BE 1)
#  [5.0, 166.0, 72.0, 19.0, 175.0, 25.8, 0.587, 51.0]      ENTRY PREDICTED => 1 (EXPECTED TO BE 1)
#  [7.0, 100.0, 0.0, 0.0, 0.0, 30.0, 0.484, 32.0]          ENTRY PREDICTED => 0 (EXPECTED TO BE 1)
#  [0.0, 118.0, 84.0, 47.0, 230.0, 45.8, 0.551, 31.0]      ENTRY PREDICTED => 0 (EXPECTED TO BE 1)
#  [7.0, 107.0, 74.0, 0.0, 0.0, 29.6, 0.254, 31.0]         ENTRY PREDICTED => 0 (EXPECTED TO BE 1)
#  [1.0, 103.0, 30.0, 38.0, 83.0, 43.3, 0.183, 33.0]       ENTRY PREDICTED => 0 (EXPECTED TO BE 0)
#  [1.0, 115.0, 70.0, 30.0, 96.0, 34.6, 0.529, 32.0]       ENTRY PREDICTED => 0 (EXPECTED TO BE 1)
